# %% [markdown]
# # Import & Export Data

# %%
import pandas as pd

# %%
url = "http://archive.ics.uci.edu/ml/machine-learning-databases/adult/adult.data"

# %%
df = pd.read_csv(url, header = None)

# %%
df.head()
# Out:
#    0                  1       2           3   4                    5   \
# 0  39          State-gov   77516   Bachelors  13        Never-married
# 1  50   Self-emp-not-inc   83311   Bachelors  13   Married-civ-spouse
# 2  38            Private  215646     HS-grad   9             Divorced
# 3  53            Private  234721        11th   7   Married-civ-spouse
# 4  28            Private  338409   Bachelors  13   Married-civ-spouse
#
#                    6               7       8        9     10  11  12  \
# 0        Adm-clerical   Not-in-family   White     Male  2174   0  40
# 1     Exec-managerial         Husband   White     Male     0   0  13
# 2   Handlers-cleaners   Not-in-family   White     Male     0   0  40
# 3   Handlers-cleaners         Husband   Black     Male     0   0  40
# 4      Prof-specialty            Wife   Black   Female     0   0  40
#
#                13      14
# 0   United-States   <=50K
# 1   United-States   <=50K
# 2   United-States   <=50K
# ...

# %%
df.to_dict()
# Out:
# {0: {0: 39,
#   1: 50,
#   2: 38,
#   3: 53,
#   4: 28,
#   5: 37,
#   6: 49,
#   7: 52,
#   8: 31,
#   9: 42,
#   10: 37,
#   11: 30,
#   12: 23,
#   13: 32,
#   14: 40,
#   15: 34,
#   16: 25,
#   17: 32,
#   18: 38,
#   19: 43,
#   20: 40,
#   21: 54,
#   22: 35,
#   23: 43,
#   24: 59,
#   25: 56,
#   26: 19,
#   27: 54,
#   28: 39,
#   29: 49,
#   30: 23,
#   31: 20,
#   32: 45,
#   33: 30,
#   34: 22,
#   35: 48,
#   36: 21,
#   37: 19,
#   38: 31,
#   39: 48,
#   40: 31,
#   41: 53,
#   42: 24,
#   43: 49,
#   44: 25,
#   45: 57,
#   46: 53,
#   47: 44,
#   48: 41,
#   49: 29,
#   50: 25,
#   51: 18,
#   52: 47,
#   53: 50,
#   54: 47,
#   55: 43,
#   56: 46,
#   57: 35,
#   58: 41,
#   59: 30,
#   60: 30,
#   61: 32,
#   62: 48,
#   63: 42,
#   64: 29,
#   65: 36,
#   66: 28,
#   67: 53,
#   68: 49,
#   69: 25,
#   70: 19,
#   71: 31,
#   72: 29,
#   73: 23,
#   74: 79,
#   75: 27,
#   76: 40,
#   77: 67,
#   78: 18,
#   79: 31,
#   80: 18,
#   81: 52,
#   82: 46,
# ...

# %%
df[1:5].to_html('adult.html')

# %%
pd.read_html('adult.html')
# Out:
# [   Unnamed: 0   0                 1       2          3   4  \
#  0           1  50  Self-emp-not-inc   83311  Bachelors  13
#  1           2  38           Private  215646    HS-grad   9
#  2           3  53           Private  234721       11th   7
#  3           4  28           Private  338409  Bachelors  13
#
#                      5                  6              7      8       9  10  \
#  0  Married-civ-spouse    Exec-managerial        Husband  White    Male   0
#  1            Divorced  Handlers-cleaners  Not-in-family  White    Male   0
#  2  Married-civ-spouse  Handlers-cleaners        Husband  Black    Male   0
#  3  Married-civ-spouse     Prof-specialty           Wife  Black  Female   0
#
#     11  12             13     14
#  0   0  13  United-States  <=50K
#  1   0  40  United-States  <=50K
#  2   0  40  United-States  <=50K
#  3   0  40           Cuba  <=50K  ]

# %%
df.to_json('del_temp_file.json')
